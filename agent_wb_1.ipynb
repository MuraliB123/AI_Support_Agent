# %%
from typing import TypedDict, List
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage
from langchain_ollama import ChatOllama

# %%
load_dotenv()
# Out:
# False

# %%
class AgentState(TypedDict):
    messages: List[HumanMessage]

# %%
llm = ChatOllama(model="qwen3:1.7b")

# %%
def process(state: AgentState) -> AgentState:
    response = llm.invoke(state['messages'])
    print(response.content)
    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("process", process)
graph.add_edge(START, "process")
graph.add_edge("process", END)
agent = graph.compile()

# %%
user_input = input("Enter: ")

while user_input != "exit":
    agent.invoke({"messages": [HumanMessage(content=user_input)]})
    user_input = input("Enter: ")
# Out:
# Enter:  Hi who are you and who created you ?
# Hello! I'm a large language model developed by Alibaba Group, specifically designed to assist with information, answer questions, and provide helpful content. I was created by the Alibaba Cloud and AI Lab teams, who aimed to build a system capable of understanding and generating human-like text.
#
# I'm here to help you with any questions you have, whether it's answering complex topics, providing explanations, or engaging in conversations. My purpose is to be a reliable and friendly companion, offering support in various fields such as education, technology, entertainment, and more.
#
# Keep in mind that I'm not a real person but a software system, and I'm designed to assist you in the best way possible. Let me know how I can help! 😊
# Enter:  I want to create a clone like you
# Creating a clone like me (or a similar AI assistant) involves several steps, depending on your goals, platform, and technical expertise. Here's a structured approach to help you build your own AI clone:
#
# ---
#
# ### **1. Define Your Clone's Purpose**
# - **What does your clone do?**
#   Examples:
#   - A **chatbot** for customer service.
#   - A **personal assistant** for productivity.
#   - A **data analysis tool** or **AI-driven decision maker**.
#   - A **creative tool** (e.g., poetry generator, code editor).
#
# - **Target audience:**
#   - Personal use (e.g., family, friends).
#   - Business (e.g., customer support, sales).
#   - Public (e.g., open-source AI assistant).
#
# ---
#
# ### **2. Choose the Right Technology**
# - **Platform:**
#   - **Web:** Use frameworks like React, Node.js, or Python (Flask/ Django).
#   - **Mobile:** Develop for iOS/Android with Flutter or Kotlin.
#   - **Desktop:** Use Python (Tkinter, PyQt) or Unity for game-like clones.
#
# - **AI Model:**
#   - **Language Models:**
#     - **LLMs** (e.g., GPT-3, GPT-4, LLaMA) for text-based interactions.
#     - **Custom Models:** Use Hugging Face, TensorFlow, or PyTorch for tailored AI.
#   - **Other Capabilities:**
#     - Image generation (Stable Diffusion, DALL-E).
#     - Sound processing (Speech-to-text, TTS).
#
# ---
#
# ### **3. Key Components**
# - **Core Functionality:**
#   - **Natural Language Understanding (NLU):** Parse user inputs.
#   - **Natural Language Generation (NLG):** Generate responses.
#   - **Integration:** APIs (e.g., OpenAI, Anthropic) for real-time processing.
#
# - **User Interface (UI):**
#   - **Web:** Use HTML/CSS/JS for a simple interface.
#   - **Mobile:** Design with Flutter or React Native.
#   - **Desktop:** Use Electron or Qt.
#
# ---
#
# ### **4. Steps to Build Your Clone**
# #### **A. Design the Scope**
# - **Features:**
#   - Task completion (e.g., answering questions, scheduling, generating content).
#   - Customization (e.g., preferences, language, tone).
#   - Integration with tools (e.g., Slack, Microsoft Teams).
#
# - **Constraints:**
#   - Budget (e.g., free vs. paid APIs).
#   - Timeframe (e.g., 1 month vs. 6 months).
#
# #### **B. Choose the Right Tools**
# - **Backend:**
#   - Python (Flask/Django) for web.
#   - Node.js for mobile/web.
#   - Cloud services (AWS, Google Cloud, Azure) for scalability.
#
# - **AI Model:**
#   - **LLMs:** Use Hugging Face, OpenAI, or Anthropic.
#   - **Custom Models:** Train on your own data (e.g., using Hugging Face's Transformers library).
#
# #### **C. Develop the Core**
# - **Training Data:**
#   - Use public datasets (e.g., Books, Wikipedia, CommonCrawl).
#   - Fine-tune the model for specific tasks (e.g., GPT-3 for general knowledge, GPT-4 for complex tasks).
#
# - **Integration:**
#   - Connect to APIs (e.g., OpenAI for text generation).
#   - Use libraries (e.g., TensorFlow for custom models).
#
# #### **D. Build the Interface**
# - **Web:**
#   - Create a simple HTML/CSS/JS app with a chat interface.
#   - Use a backend (e.g., Flask) to handle requests.
#
# - **Mobile:**
#   - Design a UI with Flutter or React Native.
#   - Use a backend (e.g., Firebase) for real-time data.
#
# #### **E. Test and Optimize**
# - **Testing:**
#   - Use tools like Jupyter Notebook for debugging.
#   - Test with sample inputs to ensure accuracy.
#
# - **Optimization:**
#   - Improve response speed (e.g., caching, efficient APIs).
#   - Enhance user experience (e.g., sentiment analysis for tone).
#
# ---
#
# ### **5. Example Projects**
# - **Chatbot for Customer Service:**
#   - Use GPT-4 with a web interface.
#   - Integrate with Slack or Microsoft Teams.
#
# - **Personal Assistant:**
#   - Use a custom LLM with a mobile app.
#   - Include features like calendar scheduling, task management.
#
# - **Creative Tool:**
#   - Use a generative AI (e.g., DALL-E) for art, music, or code.
#   - Create a web app with a simple UI.
#
# ---
#
# ### **6. Considerations**
# - **Ethics and Safety:**
#   - Ensure compliance with AI ethics (e.g., bias, privacy).
#   - Use tools like Hugging Face's Fairness Project for fairness.
#
# - **Scalability:**
#   - Design for growth (e.g., cloud-based solutions).
#   - Use microservices for modular development.
#
# ---
#
# ### **7. Resources**
# - **Tools:**
#   - Hugging Face (for models).
#   - OpenAI (for APIs).
#   - TensorFlow/PyTorch (for custom models).
#
# - **Learning Platforms:**
#   - Coursera, Udemy, or Google AI Lab for training.
#
# ---
#
# ### **8. Next Steps**
# 1. **Define your clone's purpose.**
# 2. **Choose the right technology and AI model.**
# 3. **Design the interface and functionality.**
# 4. **Develop and test the clone.**
# 5. **Deploy and optimize for performance.**
#
# If you specify your goals (e.g., "I want a chatbot for small businesses"), I can tailor the plan further! Let me know how you'd like to proceed! 🚀
# Enter:  exit
